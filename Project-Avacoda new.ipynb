# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('avacoda.csv')
df
# Out:
#              Date  AvgPrice  Total Volume     4046       4225    4770  \
# 0      12/27/2015      1.33      64236.62  1036.74   54454.85   48.16
# 1      12/20/2015      1.35      54876.98   674.28   44638.81   58.33
# 2      12/13/2015      0.93     118220.22   794.70  109149.67  130.50
# 3       12/6/2015      1.08      78992.15  1132.00   71976.41   72.58
# 4      11/29/2015      1.28      51039.60   941.48   43838.39   75.78
# ...           ...       ...           ...      ...        ...     ...
# 18244    2/4/2018      1.63      17074.83  2046.96    1529.20    0.00
# 18245   1/28/2018      1.71      13888.04  1191.70    3431.50    0.00
# 18246   1/21/2018      1.87      13766.76  1191.92    2452.79  727.94
# 18247   1/14/2018      1.93      16205.22  1527.63    2981.04  727.01
# 18248    1/7/2018      1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# ...

# %%
df.shape
# Out:
# (18249, 13)

# %%
df.columns
# Out:
# Index(['Date', 'AvgPrice', 'Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          18249 non-null  object
#  1   AvgPrice      18249 non-null  float64
#  2   Total Volume  18249 non-null  float64
#  3   4046          18249 non-null  float64
#  4   4225          18249 non-null  float64
#  5   4770          18249 non-null  float64
#  6   Total Bags    18249 non-null  float64
#  7   Small Bags    18249 non-null  float64
#  8   Large Bags    18249 non-null  float64
#  9   XLarge Bags   18249 non-null  float64
#  10  type          18249 non-null  object
#  11  year          18249 non-null  int64
#  12  region        18249 non-null  object
# dtypes: float64(9), int64(1), object(3)
# memory usage: 1.8+ MB

# %%
df["region"].unique()
df["region"].value_counts()
# Out:
# Denver                 338
# GrandRapids            338
# Atlanta                338
# RichmondNorfolk        338
# Albany                 338
# MiamiFtLauderdale      338
# Louisville             338
# Orlando                338
# CincinnatiDayton       338
# Jacksonville           338
# NewOrleansMobile       338
# Northeast              338
# Chicago                338
# Seattle                338
# Roanoke                338
# StLouis                338
# HarrisburgScranton     338
# Southeast              338
# HartfordSpringfield    338
# LosAngeles             338
# Nashville              338
# Midsouth               338
# Charlotte              338
# Detroit                338
# Tampa                  338
# California             338
# Houston                338
# Indianapolis           338
# SouthCarolina          338
# Portland               338
# Boise                  338
# Plains                 338
# BaltimoreWashington    338
# BuffaloRochester       338
# ...

# %%
df["type"].unique()
df["type"].value_counts()
# Out:
# conventional    9126
# organic         9123
# Name: type, dtype: int64

# %%
df.describe()
# Out:
#            AvgPrice  Total Volume          4046          4225          4770  \
# count  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# mean       1.405978  8.506440e+05  2.930084e+05  2.951546e+05  2.283974e+04
# std        0.402677  3.453545e+06  1.264989e+06  1.204120e+06  1.074641e+05
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.100000  1.083858e+04  8.540700e+02  3.008780e+03  0.000000e+00
# 50%        1.370000  1.073768e+05  8.645300e+03  2.906102e+04  1.849900e+02
# 75%        1.660000  4.329623e+05  1.110202e+05  1.502069e+05  6.243420e+03
# max        3.250000  6.250565e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags          year
# count  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000  18249.000000
# mean   2.396392e+05  1.821947e+05  5.433809e+04    3106.426507   2016.147899
# ...

# %% [markdown]
# Observation:
#     Difference between 75% and max is large in avgprice,smallbags,xlargebags,largebags,smallbags
#     Mean is greater than median for totalvolume,4046,largebags,xlargebags
#     avgprice min is 0.44 max is 3.25

# %%
sns.heatmap(df.isnull())

# %%
#Correlation 
dfcor=df.corr()
plt.figure(figsize=(8,6))
sns.heatmap(dfcor,annot=True,fmt='.0%')

# %%
plt.figure(figsize=(8,6))
df.drop('AvgPrice',axis=1).corrwith(df['AvgPrice']).plot(kind='bar',grid=True)

# %% [markdown]
# Observation:
#     Year is postively corelated,rest all columns are highly negatively corellated

# %% [markdown]
# Analysis

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='type',data=df)
plt.title('Avacoda')
print(df['type'].value_counts())
# Out:
# conventional    9126
# organic         9123
# Name: type, dtype: int64

# %%
sns.barplot(x="type",y="AvgPrice",data=df)
print(df.groupby('type')['AvgPrice'].value_counts())
# Out:
# type          AvgPrice
# conventional  1.15        167
#               0.99        166
#               1.08        166
#               1.13        166
#               0.98        165
#                          ...
# organic       3.04          1
#               3.05          1
#               3.12          1
#               3.17          1
#               3.25          1
# Name: AvgPrice, Length: 414, dtype: int64

# %% [markdown]
# Observation:Organic is more expensive than conventional type

# %%
sns.barplot(x="year",y="AvgPrice",data=df)
print(df.groupby('year')['AvgPrice'].value_counts())
# Out:
# year  AvgPrice
# 2015  1.03        85
#       0.98        83
#       0.99        81
#       1.09        78
#       1.08        77
#                   ..
# 2018  2.16         1
#       2.18         1
#       2.22         1
#       2.27         1
#       2.30         1
# Name: AvgPrice, Length: 835, dtype: int64

# %% [markdown]
# Observation:Avg price of avacado is high in 2017 when compared to others years

# %%
sns.barplot(x="year",y="Total Volume",data=df)
print(df.groupby('year')['Total Volume'].value_counts())
# Out:
# year  Total Volume
# 2015  84.56           1
#       379.82          1
#       419.98          1
#       482.26          1
#       530.96          1
#                      ..
# 2018  41386314.12     1
#       42939821.55     1
#       43167806.09     1
#       43409835.75     1
#       62505646.52     1
# Name: Total Volume, Length: 18244, dtype: int64

# %% [markdown]
# Observation:Total volume sales is high in 2018 when compared to others years

# %%
g = sns.catplot(data=df, y='AvgPrice',kind='bar', x='region')
g.fig.set_figwidth(20)
g.fig.set_figheight(10)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Observation:Harford,Newyork and sansfansico has the highest avg price

# %%
g = sns.catplot(data=df, y='Total Volume',kind='bar', x='region')
g.fig.set_figwidth(20)
g.fig.set_figheight(10)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Observation:TotalUS has more sales than compared to others

# %%
g = sns.catplot(data=df, y='Total Bags',kind='bar', x='region')
g.fig.set_figwidth(20)
g.fig.set_figheight(10)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Observation:Total bags(small large and xl) has more sales in TotalUS

# %%
sns.barplot(x="year",y="Total Bags",data=df)
print(df.groupby('year')['Total Bags'].value_counts())
# Out:
# year  Total Bags
# 2015  0.00           15
#       300.00          4
#       106.67          3
#       260.00          3
#       263.33          3
#                      ..
# 2018  15051877.14     1
#       15102426.94     1
#       15972492.07     1
#       16394524.11     1
#       19373134.37     1
# Name: Total Bags, Length: 18152, dtype: int64

# %% [markdown]
# Observation:Total bags(small large and xl) has more sales in 2018

# %%
x=df['Total Bags']
y=df['Total Volume']
plt.scatter(x,y)
plt.show()

# %%
sns.violinplot(df["AvgPrice"])

# %% [markdown]
# Observation:avg price is between 1-1.5

# %%
df1=df.drop(["Date"],axis=1)

# %%
from sklearn import preprocessing
le=preprocessing.LabelEncoder()
list1=['type','region']
for val in list1:
    df1[val]=le.fit_transform(df1[val].astype(str))

# %%
#Outliers
from scipy.stats import zscore
z=np.abs(zscore(df1))
threshold=3
print(np.where(z>3))
df_new=df1[(z<3).all(axis=1)]
df_new
# Out:
# (array([  346,   359,   780, ..., 17304, 17402, 17428], dtype=int64), array([2, 2, 8, ..., 0, 0, 0], dtype=int64))
#        AvgPrice  Total Volume     4046       4225    4770  Total Bags  \
# 0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4          1.28      51039.60   941.48   43838.39   75.78     6183.95
# ...         ...           ...      ...        ...     ...         ...
# 18244      1.63      17074.83  2046.96    1529.20    0.00    13498.67
# 18245      1.71      13888.04  1191.70    3431.50    0.00     9264.84
# 18246      1.87      13766.76  1191.92    2452.79  727.94     9394.11
# 18247      1.93      16205.22  1527.63    2981.04  727.01    10969.54
# 18248      1.62      17489.58  2894.77    2356.13  224.53    12014.15
#
# ...

# %%
print(df.shape) #dataset
print(df_new.shape) #Removed Outliers
# Out:
# (18249, 13)
# (17651, 12)

# %%
df_new.skew()
# Out:
# AvgPrice        0.377432
# Total Volume    3.767138
# 4046            4.909848
# 4225            4.455745
# 4770            5.117170
# Total Bags      4.066771
# Small Bags      4.222706
# Large Bags      5.053434
# XLarge Bags     6.135607
# type           -0.037741
# year            0.229976
# region          0.012798
# dtype: float64

# %%
collist=df_new.columns.values
ncol=10
nrow=20
for i in df_new.columns:
    sns.distplot(df_new[i])
    plt.show()

# %%
plt.figure(figsize=(16,16))
for i in range (0,len(collist)):
    plt.subplot(nrow,ncol,i+1)
    sns.distplot(df_new[collist[i]])

# %% [markdown]
# Observation:4046,4225,4770,largebags,xlargebags are right skew. Power transform method will be applied to removed skewness

# %%
#Remove skewness
import numpy as np
from sklearn.preprocessing import power_transform
pt=power_transform(df_new,method='yeo-johnson')
new=pd.DataFrame(pt,columns=df_new.columns)

# %%
df_new.skew()
# Out:
# AvgPrice        0.377432
# Total Volume    3.767138
# 4046            4.909848
# 4225            4.455745
# 4770            5.117170
# Total Bags      4.066771
# Small Bags      4.222706
# Large Bags      5.053434
# XLarge Bags     6.135607
# type           -0.037741
# year            0.229976
# region          0.012798
# dtype: float64

# %%
df_x=df_new.drop(columns=['AvgPrice'])
y=pd.DataFrame(df_new['AvgPrice'])
x=pd.DataFrame(df_x)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x=pd.DataFrame(x,columns=df_x.columns)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=42)

# %%
print(x_train.shape, '\t', x_test.shape)
print(y_train.shape, '\t', y_test.shape)
# Out:
# (12355, 11) 	 (5296, 11)
# (12355, 1) 	 (5296, 1)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.linear_model import LinearRegression
max_r_score=0
for r_state in range(42,100):
    reg=LinearRegression()
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=r_state)
    reg.fit(x_train,y_train)
    y_pred=reg.predict(x_test)
    r2_scr=r2_score(y_test,y_pred)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state
print("max r2 score corresponding to ",final_r_state,"is",max_r_score)
# Out:
# max r2 score corresponding to  84 is 0.4334408301942052

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn import linear_model
model=[LinearRegression(),DecisionTreeRegressor(),KNeighborsRegressor(),SVR(),Lasso(),Ridge(),ElasticNet()]
for m in model:
    m.fit(x_train,y_train)
    print('score',m,m.score(x_train,y_train))
    predm=m.predict(x_test)
    print('mean abs error',mean_absolute_error(y_test,predm))
    print('mean square error',mean_squared_error(y_test,predm))
    print('RMSE',np.sqrt(mean_squared_error(y_test,predm)))
    print("r2score",r2_score(y_test,predm))
    print("*********************************************")
    print("\n")
# Out:
# score LinearRegression() 0.40949556388259534
# mean abs error 0.22430439478360276
# mean square error 0.08385936041161145
# RMSE 0.28958480694195865
# r2score 0.42399988870551586
# *********************************************
#
#
# score DecisionTreeRegressor() 1.0
# mean abs error 0.14304729538374397
# mean square error 0.04564848484848485
# RMSE 0.21365506043266294
# r2score 0.6864567983336163
# *********************************************
#
#
# score KNeighborsRegressor() 0.900334122002661
# mean abs error 0.10781478334749361
# mean square error 0.024500840555083545
# RMSE 0.15652744345667804
# r2score 0.8317124431039368
# *********************************************
#
#
# score SVR() 0.5808677907495521
# mean abs error 0.18108594342018686
# mean square error 0.06090803877761574
# RMSE 0.2467955404329984
# r2score 0.5816443514184291
# *********************************************
#
#
# score Lasso() 0.0
# mean abs error 0.31430093855073993
# ...

# %% [markdown]
# Observation:
# LR-52
# DTC-100
# KNN-90
# SVR-73.5
# Lasso-0
# Ridge-52
# ElasticNet-0

# %%
#Crossvalidation
from sklearn.model_selection import cross_val_score
model=[LinearRegression(),DecisionTreeRegressor(),KNeighborsRegressor(),SVR(),Lasso(),Ridge(),ElasticNet()]
for m in model:
    m.fit(x_train,y_train)
    svcscores=cross_val_score(m,x,y,cv=5)
    print(m)
    print('score',svcscores)
    print('mean score',svcscores.mean(),'std',svcscores.std())
    print('*****************************')
# Out:
# LinearRegression()
# score [-1.63228713e-01  4.74525190e-02  3.02981452e-01 -4.74467414e-02
#  -1.37462994e+02]
# mean score -27.46464709035921 std 54.99938809873759
# *****************************
# DecisionTreeRegressor()
# score [-1.26997762 -0.20605179  0.24473293 -0.53904151 -0.40651378]
# mean score -0.435370354078061 std 0.49462655999878796
# *****************************
# KNeighborsRegressor()
# score [-0.20990591  0.17793185  0.30160505 -0.07400155 -0.10100741]
# mean score 0.01892440700328559 std 0.1900388939682333
# *****************************
# SVR()
# score [-0.16144179  0.32659998  0.21160658  0.06889505 -0.40578259]
# mean score 0.007975443142691385 std 0.26328552578342534
# *****************************
# Lasso()
# score [-3.85189856 -0.63909317 -0.04763459 -0.44449249 -0.80022956]
# mean score -1.156669674837169 std 1.3708646092588772
# *****************************
# Ridge()
# score [-0.1600173   0.04767375  0.30313248 -0.04687479 -0.00533706]
# ...

# %% [markdown]
# Observation:Best model KNNeighbors

# %%
from sklearn.model_selection import GridSearchCV
knn=KNeighborsRegressor()
parameters = {'n_neighbors':[4,5,6,7],
              'leaf_size':[1,3,5],
              'algorithm':['auto', 'kd_tree'],
              'n_jobs':[-1]}
clf=GridSearchCV(knn,parameters)
clf.fit(x,y)
clf.best_params_
# Out:
# {'algorithm': 'auto', 'leaf_size': 1, 'n_jobs': -1, 'n_neighbors': 7}

# %%
#using KNN as best model
knn=KNeighborsRegressor(algorithm='auto', leaf_size= 1, n_jobs= -1, n_neighbors= 7)
knn.fit(x_train,y_train)
print("score",knn.score(x_train,y_train))
predm=knn.predict(x_test)
print('mean abs error',mean_absolute_error(y_test,predm))
print('mean square error',mean_squared_error(y_test,predm))
print('RMSE',np.sqrt(mean_squared_error(y_test,predm)))
print("r2score",r2_score(y_test,predm))
# Out:
# score 0.8813224869472607
# mean abs error 0.11161063235829591
# mean square error 0.025531988972309398
# RMSE 0.1597873241915935
# r2score 0.8246298514866391

# %%
#RandomForestRegressor
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor(n_estimators=20,random_state=60)
rf.fit(x_train,y_train)
predrf=rf.predict(x_test)
print(rf.score(x_train,y_train))
print('mean abs error',mean_absolute_error(y_test,predrf))
print('mean square error',mean_squared_error(y_test,predrf))
print('RMSE',np.sqrt(mean_squared_error(y_test,predrf)))
print("r2score",r2_score(y_test,predrf))
# Out:
# 0.9741601724888482
# mean abs error 0.1084488813367318
# mean square error 0.02350607774001699
# RMSE 0.15331691928817573
# r2score 0.8385451149652239

# %%
#AdaBoostRegressor
from sklearn.ensemble import AdaBoostRegressor
knn=KNeighborsRegressor()
ab=AdaBoostRegressor(base_estimator=knn,n_estimators=20,learning_rate=0.1,random_state=60)
ab.fit(x_train,y_train)
predab=ab.predict(x_test)
print(ab.score(x_train,y_train))
print('mean abs error',mean_absolute_error(y_test,predab))
print('mean square error',mean_squared_error(y_test,predab))
print('RMSE',np.sqrt(mean_squared_error(y_test,predab)))
print("r2score",r2_score(y_test,predab))
# Out:
# 0.9174821666348698
# mean abs error 0.10647635230812799
# mean square error 0.02405452732936845
# RMSE 0.15509522020155375
# r2score 0.8347780098626418

# %% [markdown]
# Used Ensemble techniques- used over KNN technique
# RandomForest-83.8 best model
# Adaboost-83.4

# %%
import joblib
joblib.dump(ab,'avacado.pkl')
# Out:
# ['avacado.pkl']

# %% [markdown]
# # Classifier

# %%
df_x=df_new.drop(columns=['region'])
y=pd.DataFrame(df_new['region'])
x=pd.DataFrame(df_x)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x=pd.DataFrame(x,columns=df_x.columns)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=42)

# %%
print(x_train.shape, '\t', x_test.shape)
print(y_train.shape, '\t', y_test.shape)
# Out:
# (12355, 11) 	 (5296, 11)
# (12355, 1) 	 (5296, 1)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import AdaBoostClassifier,RandomForestClassifier,GradientBoostingClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import ExtraTreesClassifier


from sklearn import linear_model
model=[DecisionTreeClassifier(),GaussianNB(),KNeighborsClassifier(),SVC(),AdaBoostClassifier(),RandomForestClassifier(),GradientBoostingClassifier(),BaggingClassifier(),ExtraTreesClassifier()]
for m in model:
    print(m.fit(x_train,y_train))
    m.score(x_train,y_train)
    predm=m.predict(x_test)
    print("accuracy score",accuracy_score(y_test,predm))
    print("confusion matrix",confusion_matrix(y_test,predm))
    print("classification report",classification_report(y_test,predm))
    print("*********************************************")
    print("\n")
# Out:
# DecisionTreeClassifier()
# accuracy score 0.7922960725075529
# confusion matrix [[80  0  0 ...  0  0  0]
#  [ 0 69  0 ...  0  0  2]
#  [ 0  0 86 ...  0  0  2]
#  ...
#  [ 0  0  0 ... 50  0  0]
#  [ 0  0  0 ...  1 55  0]
#  [ 0  1  0 ...  0  0 61]]
# classification report               precision    recall  f1-score   support
#
#            0       0.80      0.78      0.79       103
#            1       0.68      0.70      0.69        99
#            2       0.89      0.86      0.87       100
#            3       0.76      0.81      0.78       100
#            4       0.91      0.84      0.87       103
#            5       0.72      0.74      0.73       105
#            6       0.94      0.92      0.93        89
#            7       0.89      0.81      0.85       113
#            8       0.90      0.91      0.91        94
#            9       0.76      0.69      0.73       113
#           10       0.74      0.64      0.69        92
# ...

# %% [markdown]
# Observation:
# DecisionTreeClassifier-79
# GaussianNB-29
# KNeighborsClassifier-56
# SVC-38
# AdaBoostClassifier-43
# RandomForestClassifier-89
# GradientBoostingClassifier-82
# BaggingClassifier-85
# extratree-90.5
#
# Best method-Extratree classifier

# %%
from sklearn.model_selection import cross_val_score
model=[DecisionTreeClassifier(),GaussianNB(),KNeighborsClassifier(),SVC(),AdaBoostClassifier(),RandomForestClassifier(),GradientBoostingClassifier(),BaggingClassifier(),ExtraTreesClassifier()]
for m in model:
    m.fit(x_train,y_train)
    svcscores=cross_val_score(m,x,y,cv=5,scoring='accuracy')
    print(m)
    print('score',svcscores)
    print('mean score',svcscores.mean(),'std',svcscores.std())
    print('***********************************************************')
# Out:
# DecisionTreeClassifier()
# score [0.47635231 0.68753541 0.63172805 0.53031161 0.4305949 ]
# mean score 0.5513044559598794 std 0.0955574668101983
# ***********************************************************
# GaussianNB()
# score [0.51826678 0.38526912 0.17592068 0.0286119  0.0266289 ]
# mean score 0.22693947496997455 std 0.1959596638605665
# ***********************************************************
# KNeighborsClassifier()
# score [0.47295384 0.47223796 0.39773371 0.12266289 0.0694051 ]
# mean score 0.3069986994992952 std 0.17521893346380996
# ***********************************************************
# SVC()
# score [0.43840272 0.55467422 0.35325779 0.11444759 0.08838527]
# mean score 0.3098335182595594 std 0.18197673677152268
# ***********************************************************
# AdaBoostClassifier()
# score [0.04021524 0.05127479 0.07167139 0.07252125 0.0611898 ]
# mean score 0.05937449205459054 std 0.012329058686408163
# ...

# %%
#Gridsearch for best parameter
from sklearn.model_selection import GridSearchCV
et=ExtraTreesClassifier()
parameters={'n_estimators':[400,500,600,700]}
clf=GridSearchCV(et,parameters)
clf.fit(x,y)
print('best parameters',clf.best_params_)
# Out:
# best parameters {'n_estimators': 700}

# %%
#Random foreset as best method
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor(n_estimators=700)
rf.fit(x_train,y_train)
predrf=rf.predict(x_test)
print(rf.score(x_train,y_train))
print('mean abs error',mean_absolute_error(y_test,predrf))
print('mean square error',mean_squared_error(y_test,predrf))
print('RMSE',np.sqrt(mean_squared_error(y_test,predrf)))
print("r2score",r2_score(y_test,predrf))
# Out:
# 0.9707086445079595
# mean abs error 4.294435153215365
# mean square error 51.349720238609045
# RMSE 7.165871910563923
# r2score 0.7832604288176578

# %%
import joblib
joblib.dump(ab,'avacado1.pkl')
# Out:
# ['avacado1.pkl']
